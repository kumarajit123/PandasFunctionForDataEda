# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("abc.csv")
df
# Out:
#      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
# [516 rows x 8 columns]

# %%
df["opponent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='opponent'>

# %%
df.columns
# Out:
# Index(['index', 'runs', 'opponent', 'ground', 'date', 'match', 'Match_No',
#        'total'],
#       dtype='object')

# %%
df.iloc[0:5]
# Out:
#    index  runs  opponent        ground       date match  Match_No  total
# 0      0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1      1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2      2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3      3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159

# %%
df.loc[0:5]
# Out:
#    index  runs  opponent        ground       date match  Match_No  total
# 0      0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1      1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2      2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3      3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# 5      5     2  SriLanka  Colombo(RPS)  14Sep2009   ODI         6    161

# %%
newtotal=df.assign(dfNew=df['total']+5)
newtotal
# Out:
#      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12  \
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
#      dfNew
# 0       17
# 1       54
# 2       79
# 3      133
# 4      164
# ..     ...
# 511  23666
# 512  23686
# 513  23687
# 514  23698
# 515  23714
#
# [516 rows x 9 columns]

# %%
# find sql like query
df.query('total>12 and total<74')
# Out:
#    index  runs  opponent    ground       date match  Match_No  total
# 1      1    37  SriLanka  Dambulla  20Aug2008   ODI         2     49

# %%
# only for boolean expressions
df.query('index>2 and index<5')
# Out:
#    index  runs  opponent        ground       date match  Match_No  total
# 3      3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159

# %%
df.sort_values(by='total', ascending=False)
# Out:
#      index  runs  opponent        ground       date match  Match_No  total
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
#
# [516 rows x 8 columns]

# %% [raw]
# # 10. df.sample()
# Pandas’ .sample() function allows you to randomly select rows from a DataFrame. It returns a new DataFrame containing the randomly selected rows. The function takes several parameters that allow you to control the sampling process, such as the number of rows to return, and whether or not to sample with replacement and seed for reproducibility.

# %%
df.sample()
# Out:
#      index  runs    opponent       ground       date match  Match_No  total
# 483    504    13  NewZealand  Southampton  18Jun2021  Test       484  22875

# %% [markdown]
# df.fillna(0)
# df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# index       0
# runs        0
# opponent    0
# ground      0
# date        0
# match       0
# Match_No    0
# total       0
# dtype: int64

# %% [markdown]
# # 12. df.fillna()
# The fillna() method in Pandas is used to fill in missing values in a DataFrame with a specified value or method. By default, it replaces missing values with NaN, but you can specify a different value to use instead as shown below:
#
# value: Specifies the value to use to fill in the missing values. Can be a scalar value or a dict of values for different columns.
# method: Specifies the method to use for filling in missing values. Can be 'ffill' (forward-fill) or 'bfill' (backward-fill) or 'interpolate'(interpolate values) or 'pad' or 'backfill'
# axis: Specifies the axis along which to fill in missing values. It can be 0 (rows) or 1 (columns).
# inplace: Whether to fill in the missing values in place (modifying the original DataFrame) or to return a new DataFrame with the missing values filled in.
# limit: Specifies the maximum number of consecutive missing values to fill.
# downcast: Specifies a dictionary of values to use to downcast the data types of columns.

# %% [markdown]
# 13. df.dropna()
# df.dropna() is a method used in the Pandas library to remove missing or null values from a DataFrame. It removes rows or columns from the DataFrame where at least one element is missing.
#
# You can remove all rows containing at least one missing value by calling df.dropna().
#
# df = df.dropna()
# If you want to remove only the columns that contain at least one missing value you can use df.dropna(axis=1)

# %%
df.dropna(axis=0)
# Out:
#      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
# [516 rows x 8 columns]

# %%
df.T
# Out:
#                 0          1             2             3             4
# index             0          1             2             3             4  \
# runs             12         37            25            54            31
# opponent   SriLanka   SriLanka      SriLanka      SriLanka      SriLanka
# ground     Dambulla   Dambulla  Colombo(RPS)  Colombo(RPS)  Colombo(RPS)
# date      18Aug2008  20Aug2008     24Aug2008     27Aug2008     29Aug2008
# match           ODI        ODI           ODI           ODI           ODI
# Match_No          1          2             3             4             5
# total            12         49            74           128           159
#
#                    5          6             7          8          9    ...
# index                5          6             8          9         10  ...  \
# runs                 2         16            79         30         10  ...
# opponent      SriLanka   Pakistan    WestIndies  Australia  Australia  ...
# ground    Colombo(RPS)  Centurion  Johannesburg   Vadodara     Mohali  ...
# date         14Sep2009  26Sep2009     30Sep2009  25Oct2009   2Nov2009  ...
# match              ODI        ODI           ODI        ODI        ODI  ...
# Match_No             6          7             8          9         10  ...
# total              161        177           256        286        296  ...
#
#                  506         507       508        509        510         511
# index            530         531       532        533        534         535  \
# runs              17          52        45         23         13          11
# opponent  WestIndies  WestIndies  SriLanka   SriLanka   SriLanka     England
# ground       Kolkata     Kolkata    Mohali  Bengaluru  Bengaluru  Birmingham
# date       16Feb2022   18Feb2022  4Mar2022  12Mar2022  12Mar2022    1Jul2022
# match            T20         T20      Test       Test       Test        Test
# Match_No         507         508       509        510        511         512
# total          23517       23569     23614      23637      23650       23661
#
#                  512         513         514        515
# index            536         537         538        539
# runs              20           1          11         16
# opponent     England     England     England    England
# ground    Birmingham  Birmingham  Nottingham     Lord's
# date        1Jul2022    9Jul2022   10Jul2022  14Jul2022
# match           Test         T20         T20        ODI
# Match_No         513         514         515        516
# total          23681       23682       23693      23709
#
# [8 rows x 516 columns]

# %% [markdown]
# df.merge() is a pandas function that allows you to combine two DataFrames based on one or more common columns. It is similar to SQL JOINs. The function returns a new DataFrame that contains only the rows where the values in the specified columns match between the two DataFrames.
#
# Here is an example of how to use df.merge() to combine two DataFrames based on a common column:
#
# # Create the first DataFrame
# df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
#                    'value': [1, 2, 3, 4]})
#
# # Create the second DataFrame
# df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
#                    'value': [5, 6, 7, 8]})
#
# # Merge the two DataFrames on the 'key' column
# merged_df = df1.merge(df2, on='key')
#
# # Print the merged DataFrame
# print(merged_df)
